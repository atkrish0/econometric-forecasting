# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:/DS/FORTIS.csv")

# %%
df.head()
# Out:
#    Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0  FORTIS     EQ  15-May-2017      208.40      208.40      209.65     204.05
# 1  FORTIS     EQ  16-May-2017      205.25      206.25      209.45     205.45
# 2  FORTIS     EQ  17-May-2017      207.90      208.00      210.80     204.90
# 3  FORTIS     EQ  18-May-2017      205.90      204.00      205.25     195.00
# 4  FORTIS     EQ  19-May-2017      196.85      197.80      204.90     196.45
#
#        Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0          206.75       205.25         205.66                9078354
# 1          207.70       207.90         207.86                2146212
# 2          205.30       205.90         208.01                3032479
# 3          195.80       196.85         200.05                2852401
# 4          204.20       203.55         200.95                4144993
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
x = ["Symbol", "Series", "Prev Close", "Last Price", "Average Price", "Turnover", "No. of Trades", "Deliverable Qty", "% Dly Qt to Traded Qty"]

# %%
df = df.drop(x, axis = 1)

# %%
df.head()
# Out:
#           Date  Open Price  High Price  Low Price  Close Price  \
# 0  15-May-2017      208.40      209.65     204.05       205.25
# 1  16-May-2017      206.25      209.45     205.45       207.90
# 2  17-May-2017      208.00      210.80     204.90       205.90
# 3  18-May-2017      204.00      205.25     195.00       196.85
# 4  19-May-2017      197.80      204.90     196.45       203.55
#
#    Total Traded Quantity
# 0                9078354
# 1                2146212
# 2                3032479
# 3                2852401
# 4                4144993

# %%
df.rename(columns = {"Open Price":"Open", "High Price":"High", "Low Price":"Low", "Close Price":"Close", "Total Traded Quantity":"Volume"}, inplace  = True)

# %%
df.head()
# Out:
#           Date    Open    High     Low   Close   Volume
# 0  15-May-2017  208.40  209.65  204.05  205.25  9078354
# 1  16-May-2017  206.25  209.45  205.45  207.90  2146212
# 2  17-May-2017  208.00  210.80  204.90  205.90  3032479
# 3  18-May-2017  204.00  205.25  195.00  196.85  2852401
# 4  19-May-2017  197.80  204.90  196.45  203.55  4144993

# %%
df.isna().any()
# Out:
# Date      False
# Open      False
# High      False
# Low       False
# Close     False
# Volume    False
# dtype: bool
